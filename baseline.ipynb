# %%
import pandas as pd
import os
import numpy as np
import torch

device = torch.device('cpu')

masac_data_filepath = os.path.join('Data','MaSaC', 'MaSaC_train_efr.csv')
masac_data = pd.read_csv(masac_data_filepath)

# %%
masac_data.head(20)
# Out:
#     Dialogue_Id  Speaker Emotion_name  \
# 0           0.0  monisha      neutral
# 1           0.0    sahil      neutral
# 2           0.0  monisha        anger
# 3           0.0    sahil      neutral
# 4           0.0  monisha      neutral
# 5           NaN      NaN          NaN
# 6           0.0  monisha      neutral
# 7           0.0    sahil      neutral
# 8           0.0  monisha        anger
# 9           0.0    sahil      neutral
# 10          0.0  monisha      neutral
# 11          0.0    sahil      neutral
# 12          0.0  monisha      neutral
# 13          0.0    sahil      neutral
# 14          0.0  monisha      neutral
# 15          0.0    sahil     surprise
# 16          NaN      NaN          NaN
# 17          0.0  monisha      neutral
# 18          0.0    sahil      neutral
# 19          0.0  monisha        anger
#
#                                             Utterance  Annotate(0/1)
# 0                               theek se wajan karana            0.0
# 1                                             monisha            0.0
# 2                        abhi ayi. yeh, ye bhi rakho.            0.0
# 3             monisha, iss churidaar me nara nhi hai.            1.0
# 4   to kisee aur churidaar ka nara nikalke dalo na...            0.0
# 5                                                 NaN            NaN
# 6                               theek se wajan karana            0.0
# 7                                             monisha            0.0
# 8                        abhi ayi. yeh, ye bhi rakho.            0.0
# 9             monisha, iss churidaar me nara nhi hai.            0.0
# 10  to kisee aur churidaar ka nara nikalke dalo na...            0.0
# 11                    ish churidar ka nara kaha gaya.            0.0
# 12               radde ka wajan ho jane do, deti hun.            0.0
# 13  raddee ka wajan aur churidaar ke naare ka kya ...            0.0
# 14  akhabaar ke baad magazine ka bundle bechungi n...            1.0
# 15  mera choodeedaar ka naara istemaal kiya woh bu...            0.0
# 16                                                NaN            NaN
# 17                              theek se wajan karana            0.0
# 18                                            monisha            0.0
# 19                       abhi ayi. yeh, ye bhi rakho.            0.0

# %%
mask = masac_data["Dialogue_Id"].values

flips = []
flip_id = 0
for m in mask:
    if (np.isnan(m)):
        flip_id += 1
    flips.append(flip_id)

masac_data['flip'] = flips

masac_data.head(20)
# Out:
#     Dialogue_Id  Speaker Emotion_name  \
# 0           0.0  monisha      neutral
# 1           0.0    sahil      neutral
# 2           0.0  monisha        anger
# 3           0.0    sahil      neutral
# 4           0.0  monisha      neutral
# 5           NaN      NaN          NaN
# 6           0.0  monisha      neutral
# 7           0.0    sahil      neutral
# 8           0.0  monisha        anger
# 9           0.0    sahil      neutral
# 10          0.0  monisha      neutral
# 11          0.0    sahil      neutral
# 12          0.0  monisha      neutral
# 13          0.0    sahil      neutral
# 14          0.0  monisha      neutral
# 15          0.0    sahil     surprise
# 16          NaN      NaN          NaN
# 17          0.0  monisha      neutral
# 18          0.0    sahil      neutral
# 19          0.0  monisha        anger
#
#                                             Utterance  Annotate(0/1)  flip
# 0                               theek se wajan karana            0.0     0
# 1                                             monisha            0.0     0
# 2                        abhi ayi. yeh, ye bhi rakho.            0.0     0
# 3             monisha, iss churidaar me nara nhi hai.            1.0     0
# 4   to kisee aur churidaar ka nara nikalke dalo na...            0.0     0
# 5                                                 NaN            NaN     1
# 6                               theek se wajan karana            0.0     1
# 7                                             monisha            0.0     1
# 8                        abhi ayi. yeh, ye bhi rakho.            0.0     1
# 9             monisha, iss churidaar me nara nhi hai.            0.0     1
# 10  to kisee aur churidaar ka nara nikalke dalo na...            0.0     1
# 11                    ish churidar ka nara kaha gaya.            0.0     1
# 12               radde ka wajan ho jane do, deti hun.            0.0     1
# 13  raddee ka wajan aur churidaar ke naare ka kya ...            0.0     1
# 14  akhabaar ke baad magazine ka bundle bechungi n...            1.0     1
# 15  mera choodeedaar ka naara istemaal kiya woh bu...            0.0     1
# 16                                                NaN            NaN     2
# 17                              theek se wajan karana            0.0     2
# 18                                            monisha            0.0     2
# 19                       abhi ayi. yeh, ye bhi rakho.            0.0     2

# %%
import pickle

with open('./Data/MaSaC/sent2emb.pickle', 'rb') as f:
    sent2emb = pickle.load(f)

# %%
import torch
from utilities import preprocess_text
index = 0
this_index_data = masac_data[masac_data['flip'] == index]
triggers = torch.tensor(this_index_data['Annotate(0/1)'].values)
all_utt = this_index_data['Utterance'].apply(preprocess_text).values

torch.stack([sent2emb[utt] for utt in all_utt]).shape
# Out:
# torch.Size([5, 768])

# %%
masac_data = masac_data.dropna()

# %%
# [type(x) for x in masac_data['Utterance'].values]
# masac_data['Utterance'].values[5]

# %%
from torch.utils.data import Dataset, IterableDataset
import torch
from utilities import preprocess_text

class MaSaCFlipDataset(Dataset):
    def __init__(self, masac_data: pd.DataFrame):
        self.data = masac_data
    
    def __getitem__(self, index):
        this_index_data = self.data[self.data['flip'] == index]
        triggers = torch.tensor(this_index_data['Annotate(0/1)'].values)
        try:
            all_utt = this_index_data['Utterance'].apply(preprocess_text).values
        except Exception as e:
            print()
            raise e
        emb_all_utt = [sent2emb[utt] for utt in all_utt]
        emb_last_utt = torch.tensor(sent2emb[all_utt[-1]])
        return [[torch.cat([e, emb_last_utt]), trigger] for e, trigger in zip(emb_all_utt, triggers)]
        
    
    def __len__(self):
        return max(self.data['flip'])
        
        
dataset = MaSaCFlipDataset(masac_data=masac_data)

# %%
from torch.utils.data import random_split
def split_train_val(dataset, val_ratio=0.2):
    n_dataset = len(dataset)
    split_index = int(n_dataset*val_ratio)
    return [dataset[i] for i in range(split_index)], [dataset[i] for i in range(split_index, n_dataset)]

train_dataset, val_dataset = split_train_val(dataset, val_ratio=0.2)
# generator1 = torch.Generator(device=device).manual_seed(42)
# train_dataset, val_dataset = random_split(dataset, [0.8, 0.2], generator=generator1)
# Out:
# c:\Users\divya\anaconda3\envs\pytorch_cuda_py39\lib\site-packages\torch\utils\_device.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return func(*args, **kwargs)

# %%
from torch import nn
import torch.nn.functional as F
class SimpleMLPBaseline(nn.Module):
    def __init__(self, hidden_dims: list):
        super().__init__()
        self.hidden_dims = hidden_dims
        self.hiddens = []
        prev_dim = 768*2
        self.hidden1 = nn.Linear(prev_dim, hidden_dims[0])
        self.hidden2 = nn.Linear(hidden_dims[0], hidden_dims[1])
        self.hidden3 = nn.Linear(hidden_dims[1], hidden_dims[2])
    
    def forward(self, dataset):
        output = F.relu(self.hidden1(dataset))
        output = F.relu(self.hidden2(output))
        output = F.sigmoid(self.hidden3(output))
        return output

model = SimpleMLPBaseline([1024, 768, 1]).to(device)

# %%
from torch import optim
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm

writer = SummaryWriter(log_dir='./tensorboard_logs/efr_mlp_baseline_exp_1')
def train_batch(model, dataset_batch, loss_fn, optimizer):
    model.train()
    optimizer.zero_grad()
    for b_idx, b in enumerate(dataset_batch):
        probs = model(b[0].to(device)).squeeze()
        loss = loss_fn(probs, b[1].type(torch.float).to(device))
        loss /= len(dataset_batch)
        loss.backward()
        optimizer.step()
    return loss

def val_batch(model, dataset_batch, loss_fn):
    model.eval()
    with torch.inference_mode():
        probs = model(dataset_batch[0])
        loss = loss_fn(probs, dataset_batch[1])
        return loss

def train(model, train_dataset, val_dataset, epochs=10):
    loss_fn = nn.BCELoss()
    val_losses = []
    optimizer = optim.AdamW(model.parameters(), lr=1e-3, betas=(0.9, 0.98), weight_decay=1e-9)
    for epoch in range(epochs):
        for b_idx, batch in tqdm(enumerate(train_dataset), total=len(train_dataset), ncols=100, desc=f"Train epoch {epoch}"):
            train_loss = train_batch(model=model, dataset_batch=batch, loss_fn=loss_fn, optimizer=optimizer)
            writer.add_scalar('Train Loss', train_loss, b_idx)
        for b_idx, batch in tqdm(enumerate(val_dataset), total=len(val_dataset), ncols=100, desc=f"Validation epoch {epoch}"):
            val_loss  = val_batch(model, dataset_batch=batch, loss_fn=loss_fn)
            val_losses.append(val_loss)
        val_loss = np.mean(val_losses)
        writer.add_scalar('Train Loss', val_loss, epoch)
        

train(model, train_dataset, val_dataset)
# Out:
# Train epoch 0:   0%|                                                        | 0/978 [00:00<?, ?it/s]
# Train epoch 0: 100%|██████████████████████████████████████████████| 978/978 [04:09<00:00,  3.93it/s]
# Validation epoch 0:   0%|                                                  | 0/3914 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\divya\Documents\IITK\Assignments\CS779 - SNLP\Emotion-Flip-Reasoning\Import-NLP-SemEval-2024-Task-10\baseline.ipynb Cell 11 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=34'>35</a>         val_loss = np.mean(val_losses)
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=35'>36</a>         writer.add_scalar('Train Loss', val_loss, epoch)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=38'>39</a> train(model, train_dataset, val_dataset)
#
# c:\Users\divya\Documents\IITK\Assignments\CS779 - SNLP\Emotion-Flip-Reasoning\Import-NLP-SemEval-2024-Task-10\baseline.ipynb Cell 11 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=30'>31</a>     writer.add_scalar('Train Loss', train_loss, b_idx)
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=31'>32</a> for b_idx, batch in tqdm(enumerate(val_dataset), total=len(val_dataset), ncols=100, desc=f"Validation epoch {epoch}"):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=32'>33</a>     val_loss  = val_batch(model, dataset_batch=batch, loss_fn=loss_fn)
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=33'>34</a>     val_losses.append(val_loss)
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=34'>35</a> val_loss = np.mean(val_losses)
#
# c:\Users\divya\Documents\IITK\Assignments\CS779 - SNLP\Emotion-Flip-Reasoning\Import-NLP-SemEval-2024-Task-10\baseline.ipynb Cell 11 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a> model.eval()
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=18'>19</a> with torch.inference_mode():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a>     probs = model(dataset_batch[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a>     loss = loss_fn(probs, dataset_batch[1])
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a>     return loss
#
# File c:\Users\divya\anaconda3\envs\pytorch_cuda_py39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\divya\Documents\IITK\Assignments\CS779 - SNLP\Emotion-Flip-Reasoning\Import-NLP-SemEval-2024-Task-10\baseline.ipynb Cell 11 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> def forward(self, dataset):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>     output = F.relu(self.hidden1(dataset))
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a>     output = F.relu(self.hidden2(output))
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Documents/IITK/Assignments/CS779%20-%20SNLP/Emotion-Flip-Reasoning/Import-NLP-SemEval-2024-Task-10/baseline.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a>     output = F.sigmoid(self.hidden3(output))
#
# File c:\Users\divya\anaconda3\envs\pytorch_cuda_py39\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\divya\anaconda3\envs\pytorch_cuda_py39\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# TypeError: linear(): argument 'input' (position 1) must be Tensor, not list

# %%
dataset[0][0]
# Out:
# [tensor([-0.6568, -0.1915,  0.1676,  ...,  1.0275, -0.2283, -0.1334],
#         device='cuda:0'),
#  tensor(0., device='cuda:0', dtype=torch.float64)]
